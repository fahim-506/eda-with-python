# %% [markdown]
# # Pandas

# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %%
import pandas as pd

# %%
#string
country = ['India','Pakistan','USA','Nepal','Srilanka']
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
runs = [13,24,56,78,100]
pd.Series(runs)
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
marks = [50,67,99,87]
subjects = ['math','physics','cs','english']
pd.Series(marks,index=subjects)
# Out:
# math       50
# physics    67
# cs         99
# english    87
# dtype: int64

# %%
mark=pd.Series(marks,index=subjects,name='fff')

# %%
mark
# Out:
# math       50
# physics    67
# cs         99
# english    87
# Name: fff, dtype: int64

# %%
mark = {
    'maths':67,
    'english':78,
    'hindi':100
}
mark_series=pd.Series(mark,name='fahim')
mark_series
# Out:
# maths       67
# english     78
# hindi      100
# Name: fahim, dtype: int64

# %% [markdown]
# ## Series Attributes

# %%
# size
mark_series.size
# Out:
# 3

# %%
# name
mark_series.name
# Out:
# 'fahim'

# %%
mark_series.is_unique
# Out:
# True

# %%
mark_series.index
# Out:
# Index(['maths', 'english', 'hindi'], dtype='object')

# %%
mark_series.values
# Out:
# array([ 67,  78, 100])

# %% [markdown]
# ## Series using read_csv

# %%
pd.read_csv('../datasets/subs.csv')
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# with one col
# pd.read_csv('../datasets/subs.csv',squeeze=True)
s = pd.read_csv('../datasets/subs.csv').iloc[:, 0]
s
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# with two col 
vk=pd.read_csv("../datasets/kohli_ipl.csv",index_col='match_no')
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
bw = pd.read_csv('../datasets/bollywood.csv',index_col='movie')
bw
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %% [markdown]
# ### Series Method

# %%
# head and tail
s.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
s.tail()
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
movies = pd.read_csv('../datasets/bollywood.csv',index_col='movie')
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
movies.sample(3)
# Out:
#                           lead
# movie
# Calapor (film)    Hemant Gopal
# Yeh Dil         Tusshar Kapoor
# Acid Factory      Fardeen Khan

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Kashmira Shah        1
# Kartik Elangovan     1
# Karisma Kapoor       1
# Karan Sharma         1
# Zulfi Sayed          1
# Name: count, Length: 566, dtype: int64

# %%
vk.sort_values(ascending=False,inplace=True) #inplace = True   --Modify the original DataFrame (or Series) directly without returning a new copy
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 vk.sort_values(ascending=False,inplace=True) #inplace = True   --Modify the original DataFrame (or Series) directly without returning a new copy
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
vk.sort_index()
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %% [markdown]
# ### Series Maths Methods

# %%
vk.count()
# Out:
# runs    215
# dtype: int64

# %%
# sum -> product
s.sum()
# Out:
# np.int64(49510)

# %%
# mean -> median -> mode -> std -> var
s.mean()
# Out:
# np.float64(135.64383561643837)

# %%
#min/max
s.min()
# Out:
# np.int64(33)

# %%
# describe
vk.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %% [markdown]
# # Series Indexing

# %%
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
x[1]
# Out:
# np.int64(13)

# %%
s[0]
# Out:
# np.int64(48)

# %%
mark_series[-1]
# Out:
# /var/folders/1t/qqtm35950b74y6zwph6yt5vm0000gn/T/ipykernel_64239/1478142797.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mark_series[-1]
# np.int64(100)

# %%
# slicing
vk[5:16]
# Out:
#           runs
# match_no
# 6            9
# 7           34
# 8            0
# 9           21
# 10           3
# 11          10
# 12          38
# 13           3
# 14          11
# 15          50
# 16           2

# %%
# negetive slicing
vk[-5:]
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
movies[::2]
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# The Accidental Prime Minister (film)       Anupam Kher
# Evening Shadows                       Mona Ambegaonkar
# Fraud Saiyaan                             Arshad Warsi
# Manikarnika: The Queen of Jhansi        Kangana Ranaut
# ...                                                ...
# Raaz (2002 film)                            Dino Morea
# Waisa Bhi Hota Hai Part II                Arshad Warsi
# Kaante                                Amitabh Bachchan
# Aankhen (2002 film)                   Amitabh Bachchan
# Company (film)                              Ajay Devgn
#
# [750 rows x 1 columns]

# %%
# fancy indexing    
# vk[[1,3,4,5]]

# %% [markdown]
# ### Editing Series

# %%
mark[1]=100
mark
# Out:
# /var/folders/1t/qqtm35950b74y6zwph6yt5vm0000gn/T/ipykernel_64239/4234314580.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   mark[1]=100
# math        50
# physics    100
# cs          99
# english     87
# Name: fff, dtype: int64

# %%
mark['Bio']=81

# %%
mark
# Out:
# math        50
# physics    100
# cs          99
# english     87
# Bio         81
# Name: fff, dtype: int64

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min
len(s)
# Out:
# 365

# %%
# type conversion
list(mark)
# Out:
# [50, 100, 99, 87, 81]

# %%
dict(mark)
# Out:
# {'math': np.int64(50),
#  'physics': np.int64(100),
#  'cs': np.int64(99),
#  'english': np.int64(87),
#  'Bio': np.int64(81)}

# %%
# membership operator
'Evening Shadows' in movies.index
# Out:
# True

# %%
'Vicky Ahuja'in movies.values
# Out:
# True

# %%
# loop
for i in movies.values:
    print(i)
# Out:
# ['Vicky Kaushal']
# ['Vicky Ahuja']
# ['Anupam Kher']
# ['Emraan Hashmi']
# ['Mona Ambegaonkar']
# ['Geetika Vidya Ohlyan']
# ['Arshad Warsi']
# ['Radhika Apte']
# ['Kangana Ranaut']
# ['Nawazuddin Siddiqui']
# ['Ali Asgar']
# ['Ranveer Singh']
# ['Prit Kamani']
# ['Ajay Devgn']
# ['Sushant Singh Rajput']
# ['Amitabh Bachchan']
# ['Abhimanyu Dasani']
# ['Talha Arshad Reshi']
# ['Nawazuddin Siddiqui']
# ['Garima Agarwal']
# ['Rasika Agashe']
# ['Barun Sobti']
# ['Akshay Kumar']
# ['Zaheer Iqbal']
# ['Vidyut Jammwal']
# ['Deepika Amin']
# ['Manav Kaul']
# ['Naseeruddin Shah']
# ['Varun Dhawan']
# ['Shreyas Talpade']
# ['Tiger Shroff']
# ['Boman Irani']
# ['Ajay Devgn']
# ['Arjun Kapoor']
# ['Gavie Chahal']
# ['Prabhu Deva']
# ['Shahid Kapoor']
# ['Ayushmann Khurrana']
# ['Anupam Kher']
# ['Karanvir Bohra']
# ['Hrithik Roshan']
# ['Jimmy Sheirgill']
# ['John Abraham']
# ['Rishi Kapoor']
# ['Kangana Ranaut']
# ['Natalia Janoszek']
# ['Diljit Dosanjh']
# ['Sidharth Malhotra']
# ...

# %%
# Arithmetical operators
100+mark
# Out:
# math       150
# physics    200
# cs         199
# english    187
# Bio        181
# Name: fff, dtype: int64

# %%
vk>=50
# Out:
#            runs
# match_no
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# ...         ...
# 211       False
# 212       False
# 213        True
# 214       False
# 215       False
#
# [215 rows x 1 columns]

# %% [markdown]
# ### Boolean Indexing on Series

# %%
vk[vk>50].size
# Out:
# 215

# %%
vk[vk == 0]
# Out:
#           runs
# match_no
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ...        ...
# 211        0.0
# 212        NaN
# 213        NaN
# 214        NaN
# 215        NaN
#
# [215 rows x 1 columns]

# %%
num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting Graphs on Series

# %%
s.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20)
# Out:
# lead
# Akshay Kumar          48
# Amitabh Bachchan      45
# Ajay Devgn            38
# Salman Khan           31
# Sanjay Dutt           26
# Shah Rukh Khan        22
# Emraan Hashmi         21
# John Abraham          18
# Saif Ali Khan         18
# Sunny Deol            17
# Shahid Kapoor         17
# Tusshar Kapoor        16
# Jimmy Sheirgill       16
# Manoj Bajpayee        14
# Irrfan Khan           14
# Arjun Rampal          14
# Anupam Kher           13
# Ayushmann Khurrana    12
# Naseeruddin Shah      12
# Hrithik Roshan        12
# Name: count, dtype: int64

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Some Important Series Methods

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
import numpy as np
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# astype
import sys
sys.getsizeof(vk)
# Out:
# 3472

# %%
sys.getsizeof(vk.astype('int16'))
# Out:
# 2182

# %%
#between 
s[s.between(10,20)].size
# Out:
# 0

# %%
s
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
s.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# drop_duplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp
temp.drop_duplicates(keep='last')
# Out:
# 1    1
# 3    2
# 5    3
# 7    4
# dtype: int64

# %%
temp.duplicated().sum()
# Out:
# np.int64(4)

# %%
vk.duplicated().sum()
# Out:
# np.int64(137)

# %%
movies.drop_duplicates()
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Sssshhh...                            Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                Tanuja
# Right Here Right Now (film)                      Ankit
# Talaash: The Hunt Begins...              Rakhee Gulzar
# The Pink Mirror                        Edwin Fernandes
#
# [566 rows x 1 columns]

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# np.int64(7)

# %%
# isnull
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
# dropna()
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna()
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin() 
vk[vk.isin([49,99])]
# Out:
#           runs
# match_no
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ...        ...
# 211        NaN
# 212        NaN
# 213        NaN
# 214        NaN
# 215        NaN
#
# [215 rows x 1 columns]

# %%
#apply()
movies.apply(lambda x: x.str.split())
# Out:
#                                                      lead
# movie
# Uri: The Surgical Strike                 [Vicky, Kaushal]
# Battalion 609                              [Vicky, Ahuja]
# The Accidental Prime Minister (film)       [Anupam, Kher]
# Why Cheat India                          [Emraan, Hashmi]
# Evening Shadows                       [Mona, Ambegaonkar]
# ...                                                   ...
# Hum Tumhare Hain Sanam                 [Shah, Rukh, Khan]
# Aankhen (2002 film)                   [Amitabh, Bachchan]
# Saathiya (film)                           [Vivek, Oberoi]
# Company (film)                              [Ajay, Devgn]
# Awara Paagal Deewana                      [Akshay, Kumar]
#
# [1500 rows x 1 columns]

# %%
s.apply(lambda x:'good day' if x > s.mean() else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
# copy()
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
new= vk.head()
new
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1

# %%
new[1]=1
# Out:
# /var/folders/1t/qqtm35950b74y6zwph6yt5vm0000gn/T/ipykernel_4972/3348571978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[1]=1

# %%
new = vk.head().copy()
new
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1

# %%
new[1]=100

# %%
new
# Out:
#           runs    1
# match_no
# 1            1  100
# 2           23  100
# 3           13  100
# 4           12  100
# 5            1  100

# %%
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]
